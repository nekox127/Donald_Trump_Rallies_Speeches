# %% [markdown]
# # Corpus Collection and processing
#
# This Jupyter notebook contains the cleaning and processing a text corpus.
# The corpus comprises the full speeches delivered by Donald Trump at 35 rallies until 2021.

# %% [markdown]
# ## 1. Cleaning

# %% [markdown]
# ### 1.1. Import packages

# %%
# Import spacy
import spacy

# Import os to upload documents and metadata
import os

# Load spaCy visualizer
from spacy import displacy

# Import pandas DataFrame packages
import pandas as pd
pd.options.mode.chained_assignment = None

# %% [markdown]
# ### 1.2. Read files and extract information from filenames

# %%
# Create empty lists for file names and contents
texts = []
file_names = []
date = []
location = []

# Iterate through each file in the folder
for _file_name in os.listdir('archive'):
    # Look for only text files
    if _file_name.endswith('.txt'):
        # Append contents of each text file to text list
        texts.append(open('archive' + '/' + _file_name, 'r', encoding='utf-8').read())
        # Append name of each file to file name list
        file_names.append(_file_name)
        # Extract and append date and location of each file
        date.append(_file_name[-14:-4])
        location.append(_file_name[0:-14])

# %% [markdown]
# ### 1.3. Create a dataframe linking each file name to its original text,  the corresponding date and location of the speech

# %%
d = {'Filename':file_names,'Date':date, 'Location':location,'Document':texts}

# %%
speech_df = pd.DataFrame(d)

# %%
speech_df.head()
# Out:
#                      Filename        Date      Location  \
# 0     CharlotteMar02_2020.txt  Mar02_2020     Charlotte
# 1  NewHampshireAug15_2019.txt  Aug15_2019  NewHampshire
# 2        ToledoJan09_2020.txt  Jan09_2020        Toledo
# 3       LatrobeSep03_2020.txt  Sep03_2020       Latrobe
# 4     HendersonSep13_2020.txt  Sep13_2020     Henderson
#
#                                             Document
# 0  I want to thank you very much. North Carolina,...
# 1   Thank you very much everybody. Thank you. Wow...
# 2  Well, thank you very much. Vice President Mike...
# 3  So thank you Pennsylvania, very much. I'm thri...
# 4  Thank you, thank you. Wow. Wow, and I'm thrill...

# %% [markdown]
# ### 1.4.  Clean the text

# %%
nlp = spacy.load('en_core_web_sm')

# %%
# Thanks for this advice in the feedback!
cleaned_texts = []
for text in texts:
    # Remove the heading space of the text
    text = text.lstrip()
    # Remove Punctuations
    doc = nlp(text)
    text = ' '.join(token.text for token in doc if not token.is_punct)
    # Change text to lower case
    cleaned_text = text.lower()
    cleaned_texts.append(cleaned_text)
    
#test
cleaned_texts[1]
# Out:
# "thank you very much everybody thank you wow i will never ever let you down that i can tell you amazing and i want to thank manchester and new hampshire they 're very special you remember those primaries that primary came around and remember what happened during the primary trump should come in third or fourth and we came in easily number one and that was the beginning that was an easy one i want to thank you all this is incredible and it 's great to be back in a state that i love with thousands of hardworking patriots who are the heart and soul of america and that 's what you are we 're actually here today to officially launch our campaign to win the great state of new hampshire in 2020 and i saw some fake polls put out by the fake news media and it said that i 'm tied with three of the other candidates the democrats i 'm tied in new hampshire i do n't think so one of them has a rally he 's got 100 people so this holds 12,000 we 're full and we could fill it up four times at least we could fill it up four times but i just want to thank you all i just think it 's going to be a tremendous four years we 're going to have a tremendous four years can you believe it we only have a little more than a year to go where it all started right the greatest political movement in the history of our country and even though we had fake witch hunts on our back and all the other things that we had to go through we have taken this big beautiful ship and it 's being turned around very quickly three years ago we campaigned across the country on a pledge to make america great again and that 's exactly what we 've done i think we can honestly say it 's the greatest slogan in the history of politics in america make america great again so if you do n't mind the other candidates go they spend millions and millions of dollars on this question that i 'm going to ask you they spend millions you remember the first slogan from our opponent that 's right neither do i. neither does anybody nobody remembers the only thing i remember is the first night i went out after i heard it and i said see it 's all about her and they immediately changed it after spending like a million dollars it 's all about her that did n't work out too well that slogan was n't too good so we have to do this we have to make a decision do you give up the greatest slogan in the history of politics in our country make america great again right do we give up make america great again for a new slogan because look our country is doing great we are doing very well with china despite the fact that they want to have you believe in the contrary all you have to do is say china how you doing they 're not too happy they 're not too happy they 're losing millions of jobs the tariffs are working and they 're eating the tariffs by the way there 's no price increase you know you got ta talk to these people the fake news but do we give up and by the way the biggest beneficiary you know who have been great our great farmers have been so incredible because they 've been targeted by china and frankly they 've been targeted for a long time including by incompetent politicians that have run this country for a long time so we 're making up for a lot of lost ground but do we give up make america great for keep america great keep america great okay you ready ready i love this because it 's free and we have all the time in the world right is there anything better than a trump rally what about a sleepy joe biden rally well he 's made some beauties i sort of hope it 's him i do n't mind any of them you got pocahontas is rising we got kamala kamala is falling you got beto beto is like gone all right we 'll see what happens whoever it is i do n't know that it matters but whoever it is different different people but i do n't know i think sleepy joe may be able to limp across the finish line but today they announced that they 're going to cut way back on his appearances because he is such a disaster they 're going to h ...

# %%
speech_df['Text'] = cleaned_texts

# %%
speech_df.head()
# Out:
#                      Filename        Date      Location  \
# 0     CharlotteMar02_2020.txt  Mar02_2020     Charlotte
# 1  NewHampshireAug15_2019.txt  Aug15_2019  NewHampshire
# 2        ToledoJan09_2020.txt  Jan09_2020        Toledo
# 3       LatrobeSep03_2020.txt  Sep03_2020       Latrobe
# 4     HendersonSep13_2020.txt  Sep13_2020     Henderson
#
#                                             Document  \
# 0  I want to thank you very much. North Carolina,...
# 1   Thank you very much everybody. Thank you. Wow...
# 2  Well, thank you very much. Vice President Mike...
# 3  So thank you Pennsylvania, very much. I'm thri...
# 4  Thank you, thank you. Wow. Wow, and I'm thrill...
#
#                                                 Text
# 0  i want to thank you very much north carolina t...
# 1  thank you very much everybody thank you wow i ...
# 2  well thank you very much vice president mike p...
# 3  so thank you pennsylvania very much i 'm thril...
# 4  thank you thank you wow wow and i 'm thrilled ...

# %% [markdown]
# ### 1.5. Apply methods from NLP to generate Doc

# %%
def process_text(text):
    return nlp(text)

# %%
speech_df['Doc'] = speech_df['Text'].apply(process_text)

# %%
speech_df.head()
# Out:
#                      Filename        Date      Location  \
# 0     CharlotteMar02_2020.txt  Mar02_2020     Charlotte
# 1  NewHampshireAug15_2019.txt  Aug15_2019  NewHampshire
# 2        ToledoJan09_2020.txt  Jan09_2020        Toledo
# 3       LatrobeSep03_2020.txt  Sep03_2020       Latrobe
# 4     HendersonSep13_2020.txt  Sep13_2020     Henderson
#
#                                             Document  \
# 0  I want to thank you very much. North Carolina,...
# 1   Thank you very much everybody. Thank you. Wow...
# 2  Well, thank you very much. Vice President Mike...
# 3  So thank you Pennsylvania, very much. I'm thri...
# 4  Thank you, thank you. Wow. Wow, and I'm thrill...
#
#                                                 Text  \
# 0  i want to thank you very much north carolina t...
# 1  thank you very much everybody thank you wow i ...
# 2  well thank you very much vice president mike p...
# 3  so thank you pennsylvania very much i 'm thril...
# 4  thank you thank you wow wow and i 'm thrilled ...
#
#                                                  Doc
# 0  (i, want, to, thank, you, very, much, north, c...
# 1  (thank, you, very, much, everybody, thank, you...
# 2  (well, thank, you, very, much, vice, president...
# 3  (so, thank, you, pennsylvania, very, much, i, ...
# 4  (thank, you, thank, you, wow, wow, and, i, ', ...

# %% [markdown]
# ### 1.6. Generate Tokens

# %%
def get_token(doc):
    return [(token.text) for token in doc]

# %%
speech_df['Tokens'] = speech_df['Doc'].apply(get_token)

# %%
speech_df.head()
# Out:
#                      Filename        Date      Location  \
# 0     CharlotteMar02_2020.txt  Mar02_2020     Charlotte
# 1  NewHampshireAug15_2019.txt  Aug15_2019  NewHampshire
# 2        ToledoJan09_2020.txt  Jan09_2020        Toledo
# 3       LatrobeSep03_2020.txt  Sep03_2020       Latrobe
# 4     HendersonSep13_2020.txt  Sep13_2020     Henderson
#
#                                             Document  \
# 0  I want to thank you very much. North Carolina,...
# 1   Thank you very much everybody. Thank you. Wow...
# 2  Well, thank you very much. Vice President Mike...
# 3  So thank you Pennsylvania, very much. I'm thri...
# 4  Thank you, thank you. Wow. Wow, and I'm thrill...
#
#                                                 Text  \
# 0  i want to thank you very much north carolina t...
# 1  thank you very much everybody thank you wow i ...
# 2  well thank you very much vice president mike p...
# 3  so thank you pennsylvania very much i 'm thril...
# 4  thank you thank you wow wow and i 'm thrilled ...
#
#                                                  Doc  \
# 0  (i, want, to, thank, you, very, much, north, c...
# 1  (thank, you, very, much, everybody, thank, you...
# 2  (well, thank, you, very, much, vice, president...
# 3  (so, thank, you, pennsylvania, very, much, i, ...
# 4  (thank, you, thank, you, wow, wow, and, i, ', ...
#
#                                               Tokens
# 0  [i, want, to, thank, you, very, much, north, c...
# 1  [thank, you, very, much, everybody, thank, you...
# 2  [well, thank, you, very, much, vice, president...
# 3  [so, thank, you, pennsylvania, very, much, i, ...
# 4  [thank, you, thank, you, wow, wow, and, i, ', ...

# %% [markdown]
# ## 2. Processing

# %% [markdown]
# ### 2.1.  Add annotations : Lemmas

# %%
def get_lemma(doc):
    return [(token.lemma_) for token in doc]

# %%
speech_df['Lemmas'] = speech_df['Doc'].apply(get_lemma)

# %%
speech_df.head()
# Out:
#                      Filename        Date      Location  \
# 0     CharlotteMar02_2020.txt  Mar02_2020     Charlotte
# 1  NewHampshireAug15_2019.txt  Aug15_2019  NewHampshire
# 2        ToledoJan09_2020.txt  Jan09_2020        Toledo
# 3       LatrobeSep03_2020.txt  Sep03_2020       Latrobe
# 4     HendersonSep13_2020.txt  Sep13_2020     Henderson
#
#                                             Document  \
# 0  I want to thank you very much. North Carolina,...
# 1   Thank you very much everybody. Thank you. Wow...
# 2  Well, thank you very much. Vice President Mike...
# 3  So thank you Pennsylvania, very much. I'm thri...
# 4  Thank you, thank you. Wow. Wow, and I'm thrill...
#
#                                                 Text  \
# 0  i want to thank you very much north carolina t...
# 1  thank you very much everybody thank you wow i ...
# 2  well thank you very much vice president mike p...
# 3  so thank you pennsylvania very much i 'm thril...
# 4  thank you thank you wow wow and i 'm thrilled ...
#
#                                                  Doc  \
# 0  (i, want, to, thank, you, very, much, north, c...
# 1  (thank, you, very, much, everybody, thank, you...
# 2  (well, thank, you, very, much, vice, president...
# 3  (so, thank, you, pennsylvania, very, much, i, ...
# 4  (thank, you, thank, you, wow, wow, and, i, ', ...
#
#                                               Tokens  \
# 0  [i, want, to, thank, you, very, much, north, c...
# 1  [thank, you, very, much, everybody, thank, you...
# 2  [well, thank, you, very, much, vice, president...
# 3  [so, thank, you, pennsylvania, very, much, i, ...
# 4  [thank, you, thank, you, wow, wow, and, i, ', ...
#
#                                               Lemmas
# 0  [I, want, to, thank, you, very, much, north, c...
# 1  [thank, you, very, much, everybody, thank, you...
# 2  [well, thank, you, very, much, vice, president...
# 3  [so, thank, you, pennsylvania, very, much, I, ...
# 4  [thank, you, thank, you, wow, wow, and, I, ', ...

# %% [markdown]
# ### 2.2. Add anotations : Part-of-speech (POS) tags

# %%
def get_pos(doc):
    return [(token.pos_, token.tag_) for token in doc]

# %%
speech_df['POS'] = speech_df['Doc'].apply(get_pos)

# %%
speech_df.head()
# Out:
#                      Filename        Date      Location  \
# 0     CharlotteMar02_2020.txt  Mar02_2020     Charlotte
# 1  NewHampshireAug15_2019.txt  Aug15_2019  NewHampshire
# 2        ToledoJan09_2020.txt  Jan09_2020        Toledo
# 3       LatrobeSep03_2020.txt  Sep03_2020       Latrobe
# 4     HendersonSep13_2020.txt  Sep13_2020     Henderson
#
#                                             Document  \
# 0  I want to thank you very much. North Carolina,...
# 1   Thank you very much everybody. Thank you. Wow...
# 2  Well, thank you very much. Vice President Mike...
# 3  So thank you Pennsylvania, very much. I'm thri...
# 4  Thank you, thank you. Wow. Wow, and I'm thrill...
#
#                                                 Text  \
# 0  i want to thank you very much north carolina t...
# 1  thank you very much everybody thank you wow i ...
# 2  well thank you very much vice president mike p...
# 3  so thank you pennsylvania very much i 'm thril...
# 4  thank you thank you wow wow and i 'm thrilled ...
#
#                                                  Doc  \
# 0  (i, want, to, thank, you, very, much, north, c...
# 1  (thank, you, very, much, everybody, thank, you...
# 2  (well, thank, you, very, much, vice, president...
# 3  (so, thank, you, pennsylvania, very, much, i, ...
# 4  (thank, you, thank, you, wow, wow, and, i, ', ...
#
#                                               Tokens  \
# 0  [i, want, to, thank, you, very, much, north, c...
# 1  [thank, you, very, much, everybody, thank, you...
# 2  [well, thank, you, very, much, vice, president...
# 3  [so, thank, you, pennsylvania, very, much, i, ...
# 4  [thank, you, thank, you, wow, wow, and, i, ', ...
#
#                                               Lemmas  \
# 0  [I, want, to, thank, you, very, much, north, c...
# 1  [thank, you, very, much, everybody, thank, you...
# 2  [well, thank, you, very, much, vice, president...
# 3  [so, thank, you, pennsylvania, very, much, I, ...
# 4  [thank, you, thank, you, wow, wow, and, I, ', ...
#
#                                                  POS
# 0  [(PRON, PRP), (VERB, VBP), (PART, TO), (VERB, ...
# 1  [(VERB, VBP), (PRON, PRP), (ADV, RB), (ADV, RB...
# 2  [(INTJ, UH), (VERB, VBP), (PRON, PRP), (ADV, R...
# 3  [(ADV, RB), (VERB, VBP), (PRON, PRP), (NOUN, N...
# 4  [(VERB, VBP), (PRON, PRP), (VERB, VBP), (PRON,...

# %% [markdown]
# ### 2.3. Add anotations : Proper Nouns

# %%
def extract_proper_nouns(doc):
    return [token.text for token in doc if token.pos_ == 'PROPN']

# %%
speech_df['Proper_Nouns'] = speech_df['Doc'].apply(extract_proper_nouns)

# %%
list(speech_df.loc[[3, 34], 'Proper_Nouns'])
# Out:
# [['arnold',
#   'pennsylvania',
#   'white',
#   'house',
#   'joe',
#   'biden',
#   'china',
#   'china',
#   'virus',
#   'america',
#   'america',
#   'united',
#   'states',
#   'military',
#   'november',
#   'november',
#   'china',
#   'mr',
#   '.',
#   'congressman',
#   'china',
#   'china',
#   'china',
#   'china',
#   'democrat',
#   'run',
#   'america',
#   'america',
#   'national',
#   'guard',
#   'biden',
#   'congress',
#   'washington',
#   'march',
#   'portland',
#   'mike',
#   'schmidt',
#   'philadelphia',
#   'bernie',
#   'sanders',
#   'pennsylvania',
#   'bernie',
#   'bernie',
#   'crazy',
#   'bernie',
#   'i.',
#   'biden',
#   'florida',
#   'ohio',
#   'texas',
#   'north',
#   'carolina',
#   'south',
#   'carolina',
#   'rick',
#   'perry',
#   'rick',
#   'rick',
#   'rick',
#   'pittsburgh',
#   'pennsylvania',
#   'ohio',
#   'west',
#   'virginia',
#   'john',
#   'hughes',
#   'john',
#   'john',
#   'john',
#   'john',
#   'john',
#   'john',
#   'john',
#   'john',
#   'hey',
#   'joe',
#   'biden',
#   'china',
#   'pennsylvania',
#   'oil',
#   'pennsylvania',
#   'pennsylvania',
#   'joe',
#   'hiden',
#   'joe',
#   'hiden',
#   'joe',
#   'hiden',
#   'america',
#   'paris',
#   'united',
#   'states',
#   'beaver',
#   'beaver',
#   'county',
#   'biden',
#   'democrats',
#   'dc',
#   'democrats',
#   'washington',
#   'thomas',
#   'jefferson',
#   'thomas',
#   'jefferson',
#   'abraham',
#   'lincoln',
#   'washington',
#   'george',
#   'washington',
#   'thomas',
#   'jefferson',
#   'abraham',
#   'lincoln',
#   'andrew',
#   'jackson',
#   'washington',
#   'christopher',
#   'new',
#   'york',
#   'christopher',
#   'columbus',
#   'new',
#   'york',
#   'italians',
#   'italians',
#   'italians',
#   'biden',
#   'texas',
#   'ebay',
#   'texas',
#   'god',
#   'texas',
#   'oklahoma',
#   'george',
#   'washington',
#   'abraham',
#   'lincoln',
#   'abraham',
#   'lincoln',
#   'vp',
#   'texas',
#   'pennsylvania',
#   'massachusetts',
#   'kennedy',
#   'massachusetts',
#   'china',
#   'germany',
#   'china',
#   'india',
#   'russia',
#   'germany',
#   'mcdonald',
#   'wendy',
#   'wendy',
#   'biden',
#   'mike',
#   'walter',
#   'reed',
#   'china',
#   'china',
#   'white',
#   'house',
#   'sir',
#   'times',
#   'cnn',
#   'fake',
#   'news',
#   'cnn',
#   'biden',
#   'texas',
#   'north',
#   'carolina',
#   'florida',
#   'south',
#   'carolina',
#   'washington',
#   'first',
#   'cnn',
#   'new',
#   'york',
#   'times',
#   'white',
#   'house',
#   'mr',
#   '.',
#   'congressman',
#   'white',
#   'house',
#   'usa',
#   'white',
#   'house',
#   'dan',
#   'meuser',
#   'dan',
#   'dan',
#   'dan',
#   'fred',
#   'keller',
#   'fred',
#   'john',
#   'joyce',
#   'great',
#   'john',
#   'guy',
#   'reschenthaler',
#   'pennsylvania',
#   'kentucky',
#   'tennessee',
#   'pennsylvania',
#   'tennessee',
#   'americans',
#   'tennessee',
#   'duncan',
#   'congressman',
#   'duncan',
#   'tennessee',
#   'mike',
#   'lou',
#   'barletta',
#   'lou',
#   'lou',
#   'lamb',
#   'washington',
#   'lamb',
#   'senate',
#   'lamb',
#   'texas',
#   'rick',
#   'rick',
#   'perry',
#   'rick',
#   'rick',
#   'perry',
#   'rick',
#   'texas',
#   'texas',
#   'donald',
#   'trump',
#   'texas',
#   'hillary',
#   'hillary',
#   'hillary',
#   'utah',
#   'brazil',
#   'mexico',
#   'usmca',
#   'pennsylvania',
#   'nafta',
#   'china',
#   'china',
#   'china',
#   'united',
#   'states',
#   'pennsylvania',
#   'nafta',
#   'u.s.-mexico',
#   'canada',
#   'china',
#   'pennsylvania',
#   'china',
#   'joe',
#   'biden',
#   'china',
#   'america',
#   'america',
#   'america',
#   'afghanistan',
#   'tim',
#   'scott',
#   'south',
#   'carolina',
#   'obama',
#   'china',
#   'democrat',
#   'va',
#   'pennsylvania',
#   'iran',
#   'nuclear',
#   'israel',
#   'u.s',
#   '.',
#   'jerusalem',
#   'golan',
#   'israel',
#   'jerusalem',
#   'new',
#   'york',
#   'times',
#   'tom',
#   'friedman',
#   'middle',
#   'east',
#   'israel',
#   'israel',
#   'uae',
#   'middle',
#   'east',
#   'israel',
#   'iraq',
#   'syria',
#   'isis',
#   'al',
#   'middle',
#   'east',
#   'america',
#   'north',
#   'korea',
#   'kim',
#   'jong',
#   'un',
#   'russia',
#   'germany',
#   'germany',
#   'germany',
#   'european',
#   'union',
#   'joe',
#   'biden',
#   'nafta',
#   'china',
#   'south',
#   'korea',
#   'crooked',
#   'hillary',
#   'clinton',
#   'south',
#   'korea',
#   'biden',
#   'iraq',
#   'osama',
#   'bin',
#   'laden',
#   'middle',
#   'east',
#   'new',
#   'york',
#   'new',
#   'york',
#   'paterson',
#   'new',
#   'jersey',
#   'virginia',
#   'democrat',
#   'nevada',
#   'nevada',
#   'nevada',
#   'nevada',
#   'nevada',
#   'mike',
#   'november',
#   'russia',
#   'russia',
#   'russia',
#   'china',
#   'pennsylvania',
#   'china',
#   'biden',
#   'joe',
#   'americans',
#   'covid-19',
#   'covid-19',
#   'joe',
#   'pennsylvania',
#   'new',
#   'york',
#   'new',
#   'york',
#   'new',
#   'york',
#   'north',
#   'carolina',
#   'michigan',
#   'democrats',
#   'november',
#   'john',
#   'november',
#   'november',
#   'democrat',
#   'democrat',
#   'china',
#   'virus',
#   'world',
#   'war',
#   'ii',
#   'april',
#   'european',
#   'union',
#   'spain',
#   'france',
#   'covid-19',
#   'covid-19',
#   'europe',
#   'united',
#   'states',
#   'us',
#   'h1n1',
#   'joe',
#   'china',
#   'china',
#   'europe',
#   'italy',
#   'spain',
#   'france',
#   'europe',
#   'china',
#   'china',
#   'joe',
#   'biden',
#   'h1ni',
#   'swine',
#   'flu',
#   'president',
#   'mike',
#   'pence',
#   'mike',
#   'democrat',
#   'swine',
#   'xenophobic',
#   'china',
#   'biden',
#   'new',
#   'york',
#   'new',
#   'york',
#   'new',
#   'york',
#   'de',
#   'blasio',
#   'october',
#   'america',
#   'china',
#   'russia',
#   'ukraine',
#   'nancy',
#   'california',
#   'nancy',
#   'nancy',
#   'america',
#   'january',
#   'january',
#   'germany',
#   'america',
#   'united',
#   'states',
#   'nasa',
#   'god',
#   'america',
#   'america',
#   'pennsylvania',
#   'valley',
#   'forge',
#   'general',
#   'george',
#   'washington',
#   'washington',
#   'george',
#   'washington',
#   'george',
#   'washington',
#   'george',
#   'washington',
#   'pennsylvania',
#   'america',
#   'god',
#   'america',
#   'pennsylvania',
#   'pennsylvania',
#   'america',
#   'america',
#   'america',
#   'america',
#   'america'],
#  ['president',
#   'mike',
#   'pence',
#   'cincinnati',
#   'cincinnati',
#   'swifton',
#   'swifton',
#   'democrats',
#   'ohio',
#   'river',
#   'american',
#   'heartland',
#   'ohio',
#   'ohio',
#   'tennessee',
#   'tennessee',
#   'pennsylvania',
#   'sir',
#   'tennessee',
#   'united',
#   'states',
#   'military',
#   'america',
#   'americans',
#   'ohio',
#   'ohio',
#   'mike',
#   'african',
#   'americans',
#   'americans',
#   'americans',
#   'democrat',
#   'party',
#   'america',
#   'apart',
#   'democrat',
#   'party',
#   'americans',
#   'democrat',
#   'democrats',
#   'republicans',
#   'democrats',
#   'mexico',
#   'mexico',
#   'democrats',
#   'democrat',
#   'chicago',
#   'baltimore',
#   'el',
#   'salvador',
#   'honduras',
#   'guatemala',
#   'afghanistan',
#   'afghanistan',
#   'afghanistan',
#   'democrats',
#   'nancy',
#   'pelosi',
#   'san',
#   'francisco',
#   'hillary',
#   'hillary',
#   'crooked',
#   'hillary',
#   'america',
#   'california',
#   'california',
#   'los',
#   'angeles',
#   'san',
#   'francisco',
#   'california',
#   'democrat',
#   'i',
#   'd',
#   'rob',
#   'rob',
#   'rob',
#   'rob',
#   'voter',
#   'i',
#   'd',
#   'voter',
#   'i',
#   'd',
#   'america',
#   'americans',
#   'us',
#   'president',
#   'obama',
#   'democrat',
#   'party',
#   'ohio',
#   'americans',
#   'democrat',
#   'republicans',
#   'americans',
#   'mike',
#   'dewine',
#   'mike',
#   'dewine',
#   'mike',
#   'kentucky',
#   'matt',
#   'bevin',
#   'november',
#   'rob',
#   'portman',
#   'senator',
#   'rob',
#   'portman',
#   'great',
#   'bob',
#   'he?he',
#   'steve',
#   'chabot',
#   'brad',
#   'wenstrup',
#   'warren',
#   'davidson',
#   'andy',
#   'barr',
#   'greg',
#   'pence',
#   'fellas',
#   'ohio',
#   'keith',
#   'faber',
#   'keith',
#   'ohio',
#   'senate',
#   'president',
#   'larry',
#   'obhof',
#   'larry',
#   'larry',
#   'ohio',
#   'supreme',
#   'court',
#   'justices',
#   'sharon',
#   'kennedy',
#   'judy',
#   'french',
#   'donald',
#   'president',
#   'obama',
#   'supreme',
#   'court',
#   'united',
#   'states',
#   'supreme',
#   'court',
#   'george',
#   'washington',
#   'gop',
#   'jane',
#   'timken',
#   'aman',
#   'bob',
#   'paduchik',
#   'bob',
#   'bob',
#   'ohio',
#   'ohio',
#   'ohio',
#   'bob',
#   'paduchik',
#   'ohio',
#   'bob',
#   'gop',
#   'ohio',
#   'mike',
#   'bob',
#   'bob',
#   'ohio',
#   'ohio',
#   'bob',
#   'paduchik',
#   'bob',
#   'donald',
#   'jr',
#   '.',
#   'soviet',
#   'union',
#   'soviet',
#   'union',
#   'soviet',
#   'union',
#   'russia',
#   'russia',
#   'saudi',
#   'arabia',
#   'russia',
#   'saudi',
#   'arabia',
#   'paris',
#   'vietnam',
#   'vietnam',
#   'ohio',
#   'west',
#   'virginia',
#   'ohio',
#   'united',
#   'states',
#   'ohio',
#   'nafta',
#   'united',
#   'states',
#   'united',
#   'states',
#   'president',
#   'obama',
#   'united',
#   'states',
#   'trans',
#   'pacific',
#   'partnership',
#   'tpp',
#   'trans',
#   'pacific',
#   'partnership',
#   'usmca',
#   'mexico',
#   'canada',
#   'united',
#   'states',
#   'usmca',
#   'america',
#   'ohio',
#   'china',
#   'china',
#   'china',
#   'china',
#   'china',
#   'united',
#   'states',
#   'sleepy',
#   'joe',
#   'biden',
#   'joe',
#   'sir',
#   'china',
#   'president',
#   'xi',
#   'china',
#   'america',
#   'united',
#   'states',
#   'ohio',
#   'united',
#   'states',
#   'steel',
#   'ohio',
#   'nucor',
#   'cleveland',
#   'toledo',
#   'toledo',
#   'ohio',
#   'florida',
#   'north',
#   'carolina',
#   'south',
#   'carolina',
#   'ohio',
#   'democrats',
#   'san',
#   'francisco',
#   'san',
#   'francisco',
#   'california',
#   'new',
#   'jersey',
#   'missouri',
#   'americans',
#   'republicans',
#   'americans',
#   'white',
#   'house',
#   'cincinnati',
#   'ohio',
#   'democrats',
#   'democrats',
#   'chuck',
#   'senate',
#   'democrat',
#   'virginia',
#   'congress',
#   'god',
#   'democrats',
#   'republican',
#   'party',
#   'american',
#   'first',
#   'lady',
#   'melania',
#   'asia',
#   'europe',
#   'united',
#   'states',
#   'canada',
#   'florida',
#   'ron',
#   'desantis',
#   'ron',
#   'desantis',
#   'ron',
#   'desantis',
#   'canada',
#   'europe',
#   'europe',
#   'canada',
#   'rob',
#   'ohio',
#   'overdose',
#   'mike',
#   'va',
#   'va',
#   'va',
#   'jim',
#   'lima',
#   'lima',
#   'lima',
#   'lima',
#   'lima',
#   'lima',
#   'lima',
#   'news',
#   'lima',
#   'americans',
#   'mike',
#   'pence',
#   'america',
#   'united',
#   'states',
#   'iran',
#   'nuclear',
#   'iran',
#   'iran',
#   'iran',
#   'iran',
#   'iran',
#   'iran',
#   'israel',
#   'jerusalem',
#   'israel',
#   'america',
#   'democrat',
#   'bob',
#   'bob',
#   'bob',
#   'bob',
#   'ohio',
#   'ohio',
#   'joe',
#   'biden',
#   'congress',
#   'usa',
#   'america',
#   'america',
#   'aids',
#   'america',
#   'democrats',
#   'america',
#   'united',
#   'states',
#   'americans',
#   'god',
#   'jamestown',
#   'virginia',
#   'americans',
#   'god',
#   'ohio',
#   'america',
#   'wealthy',
#   'america',
#   'america',
#   'america',
#   'america',
#   'great',
#   'ohio']]

# %% [markdown]
# ### 2.4. Add anotations : Named Entity Labels

# %%
def extract_named_entities(doc):
    return [ent.label_ for ent in doc.ents]

# %%
speech_df['Named_Entities'] = speech_df['Doc'].apply(extract_named_entities)

# %%
speech_df['Named_Entities']
# Out:
# 0     [GPE, GPE, CARDINAL, NORP, GPE, DATE, GPE, PER...
# 1     [GPE, ORDINAL, ORDINAL, CARDINAL, CARDINAL, GP...
# 2     [PERSON, GPE, GPE, DATE, DATE, ORDINAL, DATE, ...
# 3     [GPE, DATE, GPE, DATE, ORG, PERSON, GPE, GPE, ...
# 4     [GPE, CARDINAL, NORP, DATE, GPE, DATE, ORG, DA...
# 5     [GPE, GPE, CARDINAL, NORP, DATE, GPE, CARDINAL...
# 6     [GPE, CARDINAL, DATE, NORP, GPE, TIME, EVENT, ...
# 7     [DATE, GPE, CARDINAL, GPE, DATE, DATE, ORDINAL...
# 8     [GPE, GPE, GPE, TIME, TIME, DATE, GPE, GPE, GP...
# 9     [GPE, GPE, CARDINAL, GPE, GPE, NORP, DATE, CAR...
# 10    [GPE, GPE, GPE, DATE, LOC, CARDINAL, NORP, DAT...
# 11    [GPE, TIME, GPE, NORP, FAC, NORP, CARDINAL, GP...
# 12    [CARDINAL, GPE, MONEY, GPE, GPE, NORP, CARDINA...
# 13    [DATE, CARDINAL, CARDINAL, CARDINAL, TIME, PER...
# 14    [PERSON, QUANTITY, PERSON, GPE, DATE, QUANTITY...
# 15    [GPE, GPE, GPE, CARDINAL, NORP, DATE, DATE, DA...
# 16    [GPE, PERSON, DATE, DATE, GPE, CARDINAL, GPE, ...
# 17    [GPE, CARDINAL, NORP, GPE, DATE, GPE, DATE, CA...
# 18    [PERSON, GPE, ORDINAL, DATE, GPE, PERSON, GPE,...
# 19    [PERSON, GPE, GPE, NORP, NORP, DATE, CARDINAL,...
# 20    [PERSON, TIME, GPE, GPE, CARDINAL, DATE, NORP,...
# 21    [GPE, CARDINAL, NORP, CARDINAL, DATE, CARDINAL...
# 22    [GPE, DATE, DATE, DATE, GPE, DATE, DATE, GPE, ...
# 23    [CARDINAL, DATE, NORP, TIME, NORP, GPE, TIME, ...
# 24    [GPE, GPE, PERSON, CARDINAL, NORP, DATE, GPE, ...
# 25    [DATE, GPE, CARDINAL, NORP, DATE, DATE, ORG, P...
# 26    [GPE, CARDINAL, NORP, CARDINAL, DATE, CARDINAL...
# 27    [CARDINAL, NORP, DATE, DATE, ORG, PERSON, GPE,...
# 28    [GPE, DATE, PERSON, GPE, DATE, DATE, GPE, ORG,...
# 29    [NORP, DATE, DATE, DATE, GPE, DATE, ORG, CARDI...
# 30    [PERSON, PERSON, GPE, GPE, CARDINAL, NORP, DAT...
# 31    [GPE, GPE, GPE, CARDINAL, NORP, DATE, DATE, GP...
# 32    [GPE, GPE, ORG, DATE, GPE, CARDINAL, GPE, DATE...
# 33    [GPE, PERSON, PERSON, TIME, TIME, CARDINAL, GP...
# 34    [PERSON, GPE, GPE, TIME, TIME, NORP, TIME, NOR...
# Name: Named_Entities, dtype: object

# %% [markdown]
# ### 2.5. Add anotations : Named Entity Objects

# %%
def extract_named_entities(doc):
    return [ent for ent in doc.ents]

# %%
speech_df['NE_Words'] = speech_df['Doc'].apply(extract_named_entities)

# %%
speech_df['NE_Words']
# Out:
# 0     [(north, carolina), (charlotte), (thousands), ...
# 1     [(new, hampshire), (third), (fourth), (number,...
# 2     [(mike, pence), (toledo), (toledo), (a, year),...
# 3     [(pennsylvania), (61, days), (pennsylvania), (...
# 4     [(henderson), (thousands), (american), (51, da...
# 5     [(toledo), (ohio), (thousands), (american), (4...
# 6     [(arizona), (thousands), (november), (democrat...
# 7     [(christmas), (michigan), (thousands), (americ...
# 8     [(california), (pennsylvania), (pennsylvania),...
# 9     [(houston), (texas), (one), (america), (india)...
# 10    [(colorado), (colorado), (colorado), (the, yea...
# 11    [(dallas), (tonight), (texas), (american), (al...
# 12    [(two), (japan), (three, 40, billion), (japan)...
# 13    [(the, day), (20,000), (25,000), (close, to, 1...
# 14    [(joe, biden), (122, degrees), (joe, biden), (...
# 15    [(north, carolina), (north, carolina), (winsto...
# 16    [(oklahoma), (mike), (weeks), (today), (oklaho...
# 17    [(mexico), (thousands), (american), (america),...
# 18    [(mike), (north, carolina, 's), (ninth), (tomo...
# 19    [(mike), (pennsylvania), (pennsylvania), (amer...
# 20    [(tupelo), (tonight), (mississippi), (mississi...
# 21    [(new, hampshire), (thousands), (democrats), (...
# 22    [(las, vegas), (tomorrow), (tomorrow), (yester...
# 23    [(thousands), (manchester, 2016), (american), ...
# 24    [(nevada), (douglas, county), (douglas, county...
# 25    [(the, last, three, and, a, half, years), (mic...
# 26    [(south, carolina), (thousands), (american), (...
# 27    [(thousands), (american), (47, days), (four, m...
# 28    [(wisconsin), (a, few, years, ago), (donald, t...
# 29    [(american), (last, year), (the, best, year), ...
# 30    [(lee, greenwood), (lee), (kentucky), (kentuck...
# 31    [(north, carolina), (north, carolina), (north,...
# 32    [(new, jersey), (new, jersey), (the, new, jers...
# 33    [(north, carolina), (mike), (mike), (all, nigh...
# 34    [(mike, pence), (cincinnati), (cincinnati), (l...
# Name: NE_Words, dtype: object

# %% [markdown]
# ### 2.6. Visualize named entity tagging in a single speech

# %%
doc = speech_df['Doc'][1]
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">thank you very much everybody thank you wow i will never ever let you down that i can tell you amazing and i want to thank manchester and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new hampshire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  they 're very special you remember those primaries that primary came around and remember what happened during the primary trump should come in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  or
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fourth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  and we came in easily
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     number one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  and that was the beginning that was an easy one i want to thank you all this is incredible and it 's great to be back in a state that i love with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of hardworking patriots who are the heart and soul of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     america
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and that 's what you are we 're actually here
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to officially launch our campaign to win the great state of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new hampshire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and i saw some fake polls put out by the fake news media and it said that i 'm tied with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the other candidates the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     democrats
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  i 'm tied in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new hampshire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  i do n't think so
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of them has a rally he 's got
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people so this holds
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  we 're full and we could fill it up
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  times at least we could fill it up
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  times but i just want to thank you all i just think it 's going to be a tremendous
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  we 're going to have a tremendous
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  can you believe it we only have a little more than a year to go where it all started right the greatest political movement in the history of our country and even though we had fake witch hunts on our back and all the other things that we had to go through we have taken this big beautiful ship and it 's being turned around very quickly
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three years ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  we campaigned across the country on a pledge to make
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     america
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  great again and that 's exactly what we 've done i think we can honestly say it 's the greatest slogan in

# %% [markdown]
# ### 2.6. Drop the 'Doc' column

# %% [markdown]
# Once the file is saved as a CSV or text, all those annotations are gone, and all we have is text. So we don’t need that column at all.
# Thanks for the advice in the feedback!

# %%
speech_df = speech_df.drop('Doc',axis = 1)

# %% [markdown]
# ## 3. Saving annotated corpus as a CSV file

# %%
speech_df.to_csv('Trump_speeches_with_spaCy_tags.csv')

# %% [markdown]
#  **<font color = blue>Thank you for your time!<font>**
